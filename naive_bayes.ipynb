# %%
# Mengimpor pustaka yang diperlukan
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split

# %%
# Membaca file diabetes.csv menggunakan pandas
diabetes = pd.read_csv('diabetes.csv')

# %%
# Menentukan variabel independen (X) dan variabel dependen (y)
X = diabetes.drop('Outcome', axis=1)
y = diabetes['Outcome']

# %%
# Memisahkan data menjadi data pelatihan dan data uji
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Membuat model Naive Bayes
nb = GaussianNB()
nb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# Membuat plot Naive Bayes
plt.figure(figsize=(10,6))
plt.scatter(X_train.iloc[:, 0], X_train.iloc[:, 1], c=y_train, cmap='coolwarm', alpha=0.7, s=100)
plt.xlabel('Glucose')
plt.ylabel('BloodPressure')
plt.title('Naive Bayes Plot')
xlim = plt.xlim()
ylim = plt.ylim()
